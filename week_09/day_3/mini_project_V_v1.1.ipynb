# %% [markdown]
# ## Identifying Duplicate Questions: Using TF-IDF

# %% [markdown]
# Over 100 million people visit Quora every month, so it's no surprise that many people ask similar (or the same) questions. Various questions with the same intent can cause people to spend extra time searching for the best answer to their question, and results in members answering multiple versions of the same question. Quora uses random forest to identify duplicated questions to provide a better experience to active seekers and writers, and offer more value to both of these groups in the long term.
# Follow the steps outlined below to build the appropriate classifier model.
#
#
# Steps:
# - Download data
# - Exploration
# - Cleaning
# - Feature Engineering
# - Modeling
#
# By the end of this project you should have **a presentation that describes the model you built** and its **performance**.

# %%
import pandas as pd
import numpy as np
import re
import pprint

from nltk import word_tokenize
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./res/data/train.csv')

# %% [markdown]
# #### Note
# There is no designated test.csv file. The train.csv file is the entire dataset. Part of the data in the train.csv file should be set aside to act as the final testing data.

# %%
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %% [markdown]
# ### Self-Briefing

# %% [markdown]
# - The point of this is project is to evaluate relationships between word meanings (not necessarily similarities between word meanings themselves).

# %% [markdown]
# The word embeddings can be summarized in the following pipeline:
# - Read the text
# - Preprocess text
# - Create (x, y) data points
# - Create one hot encoded (x, y) matrices
# - Train a neural network
# - Extract the weights from the input layer

# %% [markdown]
# ### Goals
# - Find the meaning in each sentence
# - Compare meaning between 2 sentences
# - Present the comparison in numerical terms
# - Define a threshold for determining sufficient similarity

# %% [markdown]
# ### Exploration

# %% [markdown]
# #### Shape, data types, null values

# %%
print(df.shape)
print(df.dtypes)
print(type(df['question1'][0])) # object type is pandas series; values are strings
# Out:
# (404290, 6)
# id               int64
# qid1             int64
# qid2             int64
# question1       object
# question2       object
# is_duplicate     int64
# dtype: object
# <class 'str'>

# %%
print(df.isnull().sum())
print(df[df['question1'].isnull() == True])
print(df[df['question2'].isnull() == True])
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64
#             id    qid1    qid2 question1  \
# 363362  363362  493340  493341       NaN
#
#                                                 question2  is_duplicate
# 363362  My Chinese name is Haichao Yu. What English na...             0
#             id    qid1    qid2                         question1 question2  \
# 105780  105780  174363  174364    How can I develop android app?       NaN
# 201841  201841  303951  174364  How can I create an Android app?       NaN
#
#         is_duplicate
# 105780             0
# 201841             0

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
print(df.shape)
# Out:
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64
# (404287, 6)

# %% [markdown]
# **Shape** is: (404290, 6) before dropped rows \
# **Nulls**: Not many. Not sure what those null values are supposed to represent. Perhaps they weren't properly labelled. Dropped.

# %% [markdown]
# #### Column analysis

# %%
# id is a copy of the index
sum(df.index == df['id'])
# Out:
# 404287

# %%
# just confirming that the ids are not intermittently sequenced between q1 and q2
len((df['qid1'] - df['qid2']).unique())
# Out:
# 157337

# %%
# just looking for simple patters in how the questions were separated
print(len(df['question1'].unique()))
print(len(df['question2'].unique()))
print(len(df['question1'].unique()) + len(df['question2'].unique()))
# Out:
# 290455
# 299173
# 589628

# %%
print(df.duplicated(subset=('question1', 'question2')).sum())
# Out:
# 0

# %% [markdown]
# Looking for class imbalance

# %%
df[df['is_duplicate'] == 1].value_counts().sum() / df['is_duplicate'].value_counts().sum()
# Out:
# 0.3692005926482919

# %% [markdown]
# Samples of questions that were classified as duplicates

# %%
df[df['is_duplicate'] == 1].head()
# Out:
#     id  qid1  qid2                                          question1  \
# 5    5    11    12  Astrology: I am a Capricorn Sun Cap moon and c...
# 7    7    15    16                     How can I be a good geologist?
# 11  11    23    24        How do I read and find my YouTube comments?
# 12  12    25    26               What can make Physics easy to learn?
# 13  13    27    28        What was your first sexual experience like?
#
#                                             question2  is_duplicate
# 5   I'm a triple Capricorn (Sun, Moon and ascendan...             1
# 7           What should I do to be a great geologist?             1
# 11             How can I see all my Youtube comments?             1
# 12            How can you make physics easy to learn?             1
# 13             What was your first sexual experience?             1

# %% [markdown]
# Finding specific phrases or codes

# %%
df[df[['question2', 'question2']].apply(
    lambda x: x.str.contains('\[*\]', regex=True)
    ).any(axis=1)].head(10)
# Out:
#         id  qid1  qid2                                          question1  \
# 3        3     7     8  Why am I mentally very lonely? How can I solve...
# 362    362   722   723  How do I find the zeros of the polynomial func...
# 764    764  1523  1524  What is [math]x[/math] if [math]x+\left(\dfrac...
# 1275  1275  2542  2543  How do I integrate [math]v^3(a^2-v^2)^{\frac{1...
# 1357  1357  2705  2706  How do I get my company's website on the first...
# 1478  1478  2943  2944  Why is the European society ignoring the slaug...
# 1686  1686  3357  3358  Now that Britain has voted to leave the EU, wh...
# 1923  1923  3827  3828  Given that alpha and beta are roots of the equ...
# 2437  2437  4843  4844               Why do not photons obey E = m c ^ 2?
# 2712  2712  5385  5386  What is [math]\sqrt {2+\sqrt {2+\sqrt {2+\sqrt...
#
#                                               question2  is_duplicate
# 3     Find the remainder when [math]23^{24}[/math] i...             0
# 362   How would you find the zero of the function fo...             0
# 764   What is [math]\mathop {\lim}\limits_{x \to 0^+...             0
# 1275  How do I integrate [math]\frac{x^2}{x^2-1}[/ma...             0
# 1357  How do I get my website on the first page on G...             0
# 1478  [Late 2015 / Early 2016] Why does the United K...             0
# 1686  [Before Brexit vote] What are the pros and con...             0
# 1923  The roots of the equation [math]x^2+3x-10=0[/m...             0
# 2437  How can photons have no mass and yet still hav...             0
# 2712  If [math]y=f(x)=\sqrt{x+\sqrt{x^2+\sqrt{x+\sqr...             0

# %% [markdown]
# Specific queries

# %%
df.loc[1275, 'question1']
# Out:
# 'How do I integrate [math]v^3(a^2-v^2)^{\\frac{1}{2}}[/math] by substitution?'

# %% [markdown]
# - The `id` column is a copy of the `index`
# - The questions are not intermittently sequenced.
# - The questions also do not have any obvious patterns.
# - Class imbalance is fine.
# - Quick perusal of samples suggests that there may be a need to specify numbers (404 errors, numerical codes, etc.)

# %% [markdown]
# ### Cleaning
#
# - Tokenization
# - Stopwords cleaning
# - Removing punctuation
# - Normalizing
# - Stemming

# %% [markdown]
# Make a translation table and translate. The first two parameters describe:
# 1. Text to replace (required)
# 2. Replacement text (optional)
# - Note that 1 and 2 must be of the same length.
# - The replacement is performed character for character.
#
# The third parameter allows for removal of characters given the string of characters passed.
#
# In our case, we're not replacing any strings so the first two parameters are blanked. We are, however, removing punctuation so we'll pass the characters in `string.punctuation` to remove them.

# %% [markdown]
# #### Pipeline: Split into words, remove punctuation, filter stop words, lemmatize

# %%
def lemmatize(text:str) -> str:
    from nltk.stem import WordNetLemmatizer
    
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word, 'n') for word in text]
    text = [lem.lemmatize(word, 'v') for word in text]
    text = [lem.lemmatize(word, 'a') for word in text]
    text = [lem.lemmatize(word, 'r') for word in text]
    text = [lem.lemmatize(word, 's') for word in text]
    
    return text

# %%
# define the cleaning pipeline
# this function will be applied to each sentence

def preprocess(text:str) -> str:
    from nltk import word_tokenize
    from nltk.corpus import stopwords
    
    # tokenize words with additional punctiation exceptions
    words = word_tokenize(text)
    words = [word for word in words if word.isalpha()]
            #  if word.replace('.', '', 1).isalnum() | word.replace('/', '', 1).isalnum() | word.replace('-', '', 1).isalnum()]
    
    # lowercase
    words = [word.lower() for word in words]
    
    # remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if not word in stop_words]
    
    # lemmatize
    words = lemmatize(words)
    
    # remove single characters
    words = [word for word in words if len(word) > 1]
        
    return ' '.join(words)

# %% [markdown]
# NOTES
#
# 1. I had a choice to return only unique values (removing duplicates per `question` value), but I decided against it. The meaning of the question may be better defined by assuming that repeated non-stopwords are more important to the meaning of the question than those that are not repeated.
# 2. There are numerical codes that may be relevant. I've allowed numerical values that are floats, em-dashed, and fractional.
# 3. There are many questions formatted with `[math]`. I'm unfamiliar with Quora syntax so I can't presume to know what this syntax indicates. If I were to guess, it encloses a LaTex-formatted strings.
# 4. To get better results, it may be better to mark anything between 'math' tags as a negative contribution to the comparison.

# %% [markdown]
# #### Example Queries

# %%
word_tokenize(df.loc[1275, 'question1'])
# Out:
# ['How',
#  'do',
#  'I',
#  'integrate',
#  '[',
#  'math',
#  ']',
#  'v^3',
#  '(',
#  'a^2-v^2',
#  ')',
#  '^',
#  '{',
#  '\\frac',
#  '{',
#  '1',
#  '}',
#  '{',
#  '2',
#  '}',
#  '}',
#  '[',
#  '/math',
#  ']',
#  'by',
#  'substitution',
#  '?']

# %%
preprocess(df['question1'][1275])
# Out:
# 'integrate math substitution'

# %% [markdown]
# ### Feature Engineering
#
# - tf-idf
# - word2vec
# - word count
# - number of the same words in both questions
# - ....

# %% [markdown]
# One way to tackle this problem is to maybe join both question  columns and then vectorize with the answers. Then it's easy to fit to a label.

# %%
clean1 = []
for question in df['question1']:
    clean1.append(preprocess(question))
    
df['clean_q1'] = clean1

# %%
clean2 = []
for question in df['question2']:
    clean2.append(preprocess(question))
    
df['clean_q2'] = clean2

# %%
df['cleans'] = df['clean_q1'] + ' ' + df['clean_q2']

# %% [markdown]
# This results in a single column of combined query terms.

# %% [markdown]
# ### Word embedding

# %% [markdown]
# ##### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    min_df=5,
    # max_df=0.80,
    # ngram_range=(2,2)
)

tfidf.fit(df['cleans'])
vectors_idf = tfidf.transform(df['cleans'])

# %%
tfidf.vocabulary_
# Out:
# {'step': 16648,
#  'guide': 7355,
#  'invest': 8878,
#  'share': 15764,
#  'market': 10562,
#  'india': 8484,
#  'story': 16710,
#  'kohinoor': 9587,
#  'diamond': 4749,
#  'would': 19304,
#  'happen': 7506,
#  'indian': 8485,
#  'government': 7189,
#  'steal': 16637,
#  'back': 1434,
#  'increase': 8457,
#  'speed': 16420,
#  'internet': 8794,
#  'connection': 3656,
#  'use': 18484,
#  'vpn': 18897,
#  'hack': 7407,
#  'dns': 5041,
#  'mentally': 10849,
#  'lonely': 10165,
#  'solve': 16277,
#  'find': 6394,
#  'remainder': 14620,
#  'math': 10645,
#  'divide': 5008,
#  'one': 12293,
#  'dissolve': 4971,
#  'water': 19000,
#  'sugar': 16903,
#  'salt': 15262,
#  'methane': 10912,
#  'carbon': 2620,
#  'di': 4731,
#  'oxide': 12578,
#  'fish': 6425,
#  'survive': 17025,
#  'astrology': 1175,
#  'capricorn': 2603,
#  'sun': 16931,
#  'cap': 2582,
#  'moon': 11303,
#  'rise': 14945,
#  'say': 15377,
#  'triple': 17912,
#  'ascendant': 1079,
#  'buy': 2444,
#  'keep': 9405,
#  'active': 178,
#  'far': 6195,
#  'phone': 13098,
#  'video': 18719,
#  'game': 6832,
#  'good': 7153,
#  'geologist': 6974,
#  'great': 7270,
#  'instead': 8709,
#  'motorola': 11358,
#  'company': 3490,
#  'charter': 2939,
#  'free': 6668,
#  'method': 10914,
#  'separation': 15648,
#  'slit': 16122,
#  'thing': 17511,
#  'technician': 17302,
#  'tell': 17341,
#  'durability': 5288,
#  'reliability': 14599,
#  'laptop': 9757,
#  'component': 3535,
#  'read': 14335,
#  'youtube': 19455,
#  'comment': 3458,
#  'see': 15565,
#  'make': 10405,
#  'physic': 13127,
#  'easy': 5361,
#  'learn': 9843,
#  'first': 6420,
#  'sexual': 15723,
#  'experience': 6041,
#  'like': 10005,
#  'law': 9803,
#  'change': 2911,
#  'status': 16627,
#  'student': 16779,
#  'visa': 18794,
#  'green': 7277,
#  'card': 2629,
#  'compare': 3495,
#  'immigration': 8331,
#  'canada': 2549,
#  'japan': 9099,
#  'trump': 17946,
#  'presidency': 13638,
#  'mean': 10744,
#  'current': 4181,
#  'international': 8792,
#  'master': 10617,
#  'affect': 328,
#  'presently': 13635,
#  'plan': 13239,
#  'study': 16781,
#  'manipulation': 10488,
#  'girl': 7042,
#  'want': 18960,
#  'friend': 6704,
#  'guy': 7385,
#  'reject': 14575,
#  'feel': 6281,
#  'many': 10518,
#  'quora': 14111,
#  'user': 18489,
#  'post': 13473,
#  'question': 14088,
#  'readily': 14338,
#  'answer': 813,
#  'google': 7160,
#  'people': 12938,
#  'ask': 1111,
#  'easily': 5356,
#  'best': 1786,
#  'digital': 4806,
#  'institution': 8714,
#  'banglore': 1545,
#  'institute': 8713,
#  'pune': 13965,
#  'rocket': 15004,
#  'look': 10175,
#  'white': 19143,
#  'booster': 2111,
#  'paint': 12622,
#  'cause': 2754,
#  'someone': 16289,
#  'jealous': 9131,
#  'avoid': 1360,
#  'much': 11418,
#  'kv': 9660,
#  'hp': 7990,
#  'conversion': 3788,
#  'chart': 2938,
#  'cc': 2776,
#  'horsepower': 7955,
#  'every': 5945,
#  'time': 17601,
#  'clock': 3250,
#  'number': 12084,
#  'day': 4326,
#  'hand': 7470,
#  'overlap': 12528,
#  'tip': 17618,
#  'job': 9202,
#  'interview': 8816,
#  'process': 13724,
#  'medicine': 10780,
#  'foundation': 6621,
#  'web': 19048,
#  'application': 915,
#  'framework': 6644,
#  'society': 16229,
#  'place': 13230,
#  'importance': 8370,
#  'sport': 16475,
#  'contribute': 3769,
#  'way': 19022,
#  'money': 11251,
#  'online': 12302,
#  'prepare': 13616,
#  'ca': 2458,
#  'final': 6385,
#  'know': 9566,
#  'completely': 3523,
#  'exam': 5966,
#  'despite': 4646,
#  'special': 16394,
#  'care': 2638,
#  'nose': 11995,
#  'get': 6996,
#  'stuffy': 16783,
#  'night': 11868,
#  'throne': 17551,
#  'villain': 18752,
#  'likely': 10009,
#  'give': 7050,
#  'mercy': 10861,
#  'unite': 18303,
#  'state': 16612,
#  'still': 16675,
#  'blacklist': 1966,
#  'employment': 5623,
#  'etc': 5868,
#  'citizen': 3153,
#  'political': 13360,
#  'view': 18733,
#  'average': 1346,
#  'gas': 6870,
#  'molecule': 11232,
#  'determine': 4671,
#  'travel': 17856,
#  'website': 19059,
#  'spain': 16367,
#  'think': 17512,
#  'obama': 12135,
#  'try': 17959,
#  'take': 17185,
#  'gun': 7374,
#  'away': 1372,
#  'control': 3772,
#  'initiative': 8626,
#  'already': 587,
#  'improve': 8389,
#  'skill': 16058,
#  'become': 1689,
#  'entrepreneur': 5735,
#  'next': 11821,
#  'year': 19404,
#  'old': 12264,
#  'billionaire': 1879,
#  'girlfriend': 7043,
#  'boyfriend': 2178,
#  'choose': 3062,
#  'reply': 14691,
#  'end': 5648,
#  'confuse': 3637,
#  'wish': 19230,
#  'well': 19094,
#  'disconnect': 4891,
#  'call': 2514,
#  'together': 17661,
#  'upsc': 18437,
#  'civil': 3160,
#  'service': 15685,
#  'stall': 16569,
#  'wing': 19210,
#  'fully': 6756,
#  'sweep': 17080,
#  'aircraft': 430,
#  'stop': 16704,
#  'slav': 16098,
#  'squat': 16513,
#  'leg': 9863,
#  'thick': 17503,
#  'expect': 6032,
#  'cognizant': 3355,
#  'confirmation': 3627,
#  'mail': 10387,
#  'month': 11291,
#  'trade': 17779,
#  'kid': 9488,
#  'rebel': 14371,
#  'worth': 19300,
#  'long': 10167,
#  'run': 15149,
#  'bore': 2130,
#  'university': 18309,
#  'recruit': 14433,
#  'new': 11801,
#  'grad': 7205,
#  'major': 10401,
#  'food': 6550,
#  'quick': 14093,
#  'instagram': 8695,
#  'follower': 6546,
#  'darth': 4301,
#  'vader': 18537,
#  'fight': 6361,
#  'maul': 10668,
#  'star': 16589,
#  'war': 18962,
#  'legend': 9872,
#  'character': 2922,
#  'limit': 10023,
#  'profile': 13752,
#  'description': 4624,
#  'stage': 16554,
#  'break': 2225,
#  'couple': 3921,
#  'emotionally': 5604,
#  'whether': 19129,
#  'male': 10423,
#  'female': 6291,
#  'breakup': 2231,
#  'boy': 2175,
#  'example': 5970,
#  'product': 13737,
#  'crude': 4093,
#  'oil': 12253,
#  'career': 2639,
#  'launcher': 9793,
#  'rbi': 14314,
#  'grade': 7206,
#  'preparation': 13615,
#  'program': 13760,
#  'blu': 2027,
#  'ray': 14306,
#  'play': 13262,
#  'regular': 14549,
#  'dvd': 5305,
#  'player': 13266,
#  'nd': 11686,
#  'always': 607,
#  'sad': 15200,
#  'rotate': 15071,
#  'memorable': 10826,
#  'ever': 5940,
#  'eat': 5362,
#  'delicious': 4500,
#  'dish': 4918,
#  'gst': 7331,
#  'tax': 17266,
#  'officer': 12240,
#  'homework': 7885,
#  'difficult': 4792,
#  'rsi': 15109,
#  'apply': 917,
#  'senior': 15621,
#  'lie': 9976,
#  'true': 17940,
#  'secretly': 15548,
#  'attract': 1245,
#  'rap': 14262,
#  'song': 16304,
#  'dance': 4275,
#  'suddenly': 16889,
#  'log': 10140,
#  'gmail': 7100,
#  'remember': 14628,
#  'password': 12778,
#  'realize': 14352,
#  'recovery': 14429,
#  'email': 5564,
#  'alive': 533,
#  'recover': 14428,
#  'french': 6687,
#  'gender': 6927,
#  'download': 5150,
#  'content': 3737,
#  'kickass': 9484,
#  'torrent': 17721,
#  'without': 19240,
#  'registration': 14539,
#  'trustworthy': 17955,
#  'normal': 11975,
#  'dark': 4295,
#  'ring': 14931,
#  'around': 1029,
#  'iris': 8938,
#  'eye': 6112,
#  'treat': 17867,
#  'harry': 7553,
#  'potter': 13501,
#  'book': 2097,
#  'curse': 4186,
#  'child': 3015,
#  'bad': 1461,
#  'rowling': 15097,
#  'depress': 4598,
#  'even': 5932,
#  'european': 5913,
#  'family': 6180,
#  'office': 12238,
#  'database': 4311,
#  'java': 9109,
#  'language': 9744,
#  'computer': 3560,
#  'important': 8371,
#  'store': 16707,
#  'energy': 5671,
#  'produce': 13735,
#  'lightning': 9997,
#  'possible': 13470,
#  'review': 14849,
#  'performance': 12964,
#  'test': 17417,
#  'cost': 3883,
#  'privacy': 13696,
#  'germany': 6990,
#  'come': 3436,
#  'else': 5557,
#  'lose': 10193,
#  'gain': 6815,
#  'genuinely': 6966,
#  'enjoy': 5692,
#  'salad': 15243,
#  'dress': 5200,
#  'type': 18056,
#  'immunity': 8338,
#  'different': 4787,
#  'body': 2058,
#  'narcissistic': 11601,
#  'personality': 13011,
#  'disorder': 4934,
#  'speak': 16390,
#  'english': 5686,
#  'fluently': 6511,
#  'helpful': 7691,
#  'quickbooks': 14094,
#  'auto': 1306,
#  'data': 4310,
#  'support': 16985,
#  'corrupt': 3868,
#  'file': 6370,
#  'customer': 4199,
#  'usa': 18474,
#  'rich': 14895,
#  'gambler': 6831,
#  'reach': 14325,
#  'level': 9930,
#  'fire': 6408,
#  'bullet': 2379,
#  'backward': 1454,
#  'go': 7111,
#  'fast': 6216,
#  'backwards': 1455,
#  'sound': 16335,
#  'shoot': 15863,
#  'devastation': 4691,
#  'occur': 12189,
#  'prevent': 13657,
#  'breast': 2232,
#  'cancer': 2555,
#  'account': 117,
#  'ip': 8910,
#  'address': 222,
#  'device': 4702,
#  'name': 11569,
#  'exclude': 5993,
#  'sell': 15597,
#  'purpose': 13992,
#  'life': 9981,
#  'actually': 187,
#  'bjp': 1958,
#  'strip': 16757,
#  'muslim': 11492,
#  'christian': 3077,
#  'citizenship': 3154,
#  'put': 14005,
#  'boat': 2050,
#  'rohingya': 15018,
#  'burma': 2412,
#  'model': 11190,
#  'deport': 4590,
#  'illegal': 8278,
#  'bangladeshi': 1544,
#  'right': 14918,
#  'etiquette': 5892,
#  'jehovah': 9141,
#  'witness': 19242,
#  'happy': 7511,
#  'birthday': 1932,
#  'person': 13007,
#  'open': 12324,
#  'commercial': 3462,
#  'fm': 6527,
#  'radio': 14155,
#  'station': 16616,
#  'city': 3158,
#  'procedure': 13722,
#  'hd': 7610,
#  'zealand': 19483,
#  'swiss': 17094,
#  'despise': 4645,
#  'asian': 1105,
#  'technical': 17299,
#  'employee': 5621,
#  'sale': 15247,
#  'high': 7762,
#  'salary': 15246,
#  'income': 8442,
#  'field': 6353,
#  'biotechnology': 1920,
#  'pay': 12835,
#  'fresh': 6691,
#  'height': 7672,
#  'also': 589,
#  'effect': 5444,
#  'cambodia': 2527,
#  'earthquake': 5353,
#  'kamchatca': 9334,
#  'valparaiso': 18566,
#  'difference': 4786,
#  'fairness': 6157,
#  'honest': 7901,
#  'sincere': 16003,
#  'inr': 8661,
#  'warrior': 18981,
#  'prove': 13857,
#  'grind': 7298,
#  'part': 12748,
#  'reference': 14485,
#  'class': 3187,
#  'chemistry': 2982,
#  'cbse': 2773,
#  'board': 2048,
#  'national': 11633,
#  'technology': 17308,
#  'kurukshetra': 9655,
#  'social': 16222,
#  'nitk': 11913,
#  'surathkal': 16998,
#  'karnataka': 9365,
#  'graduate': 7211,
#  'batch': 1625,
#  'lesson': 9923,
#  'junior': 9286,
#  'leave': 9849,
#  'romantic': 15035,
#  'movie': 11380,
#  'nightmare': 11873,
#  'seem': 15570,
#  'real': 14342,
#  'abstract': 70,
#  'influence': 8575,
#  'print': 13684,
#  'work': 19276,
#  'attend': 1233,
#  'caltech': 2523,
#  'jeremy': 9150,
#  'notable': 12003,
#  'folk': 6542,
#  'horcrux': 7935,
#  'associate': 1157,
#  'manager': 10454,
#  'apm': 886,
#  'early': 5346,
#  'join': 9217,
#  'management': 10453,
#  'reward': 14863,
#  'general': 6931,
#  'requirement': 14718,
#  'base': 1604,
#  'software': 16247,
#  'skype': 16081,
#  'busy': 2434,
#  'could': 3899,
#  'android': 745,
#  'really': 14353,
#  'pakistan': 12629,
#  'uri': 18462,
#  'attack': 1228,
#  'nuclear': 12070,
#  'ronald': 15044,
#  'reagan': 14340,
#  'mannerism': 10500,
#  'speech': 16419,
#  'react': 14326,
#  'strategy': 16731,
#  'union': 18294,
#  'confederate': 3611,
#  'possibly': 13471,
#  'defeat': 4443,
#  'force': 6565,
#  'gettysburg': 6999,
#  'american': 642,
#  'fiction': 6348,
#  'novel': 12026,
#  'forget': 6588,
#  'recent': 14388,
#  'demonetisation': 4532,
#  'result': 14791,
#  'gdp': 6908,
#  'short': 15874,
#  'hear': 7643,
#  'whatsapp': 19117,
#  'love': 10212,
#  'pity': 13218,
#  'competitive': 3511,
#  'hire': 7803,
#  'republic': 14708,
#  'bank': 1547,
#  'help': 7689,
#  'spam': 16368,
#  'rank': 14253,
#  'adjustment': 240,
#  'search': 15525,
#  'distribution': 4987,
#  'traffic': 17786,
#  'organic': 12399,
#  'page': 12613,
#  'second': 15539,
#  'watch': 18998,
#  'subtitle': 16860,
#  'powerful': 13518,
#  'country': 3916,
#  'world': 19291,
#  'obtain': 12174,
#  'instant': 8704,
#  'ulcer': 18126,
#  'pain': 12616,
#  'relief': 14605,
#  'low': 10215,
#  'heat': 7653,
#  'ice': 8169,
#  'china': 3031,
#  'chinese': 3032,
#  'advantage': 284,
#  'materialistic': 10642,
#  'cry': 4108,
#  'stick': 16668,
#  'tongue': 17689,
#  'picture': 13154,
#  'teen': 17315,
#  'woman': 19259,
#  'allow': 563,
#  'naked': 11565,
#  'age': 365,
#  'winston': 19214,
#  'julia': 9273,
#  'differ': 4783,
#  'similar': 15980,
#  'tool': 17695,
#  'exist': 6015,
#  'toothbrush': 17700,
#  'wet': 19110,
#  'dry': 5237,
#  'toothpaste': 17701,
#  'cheap': 2953,
#  'mark': 10559,
#  'need': 11707,
#  'imrovement': 8399,
#  'neutral': 11791,
#  'buff': 2360,
#  'declare': 4402,
#  'win': 19198,
#  'mineral': 11061,
#  'hold': 7849,
#  'electrical': 5506,
#  'charge': 2927,
#  'mystery': 11531,
#  'universe': 18308,
#  'alternative': 592,
#  'machine': 10310,
#  'imbalance': 8309,
#  'set': 15693,
#  'block': 2003,
#  'sanction': 15282,
#  'un': 18143,
#  'jem': 9144,
#  'chief': 3011,
#  'masood': 10606,
#  'azhar': 1407,
#  'future': 6794,
#  'budget': 2357,
#  'excessive': 5983,
#  'amount': 672,
#  'vitamin': 18823,
#  'miscarriage': 11098,
#  'glass': 7063,
#  'scale': 15389,
#  'two': 18050,
#  'letter': 9927,
#  'intent': 8759,
#  'recruitment': 14435,
#  'access': 99,
#  'mantra': 10508,
#  'six': 16042,
#  'party': 12763,
#  'talk': 17196,
#  'successful': 16873,
#  'course': 3927,
#  'nicmar': 11852,
#  'register': 14537,
#  'domain': 5078,
#  'site': 16034,
#  'men': 10832,
#  'young': 19450,
#  'strong': 16762,
#  'structure': 16767,
#  'shape': 15761,
#  'compression': 3547,
#  'cord': 3837,
#  'matter': 10661,
#  'human': 8032,
#  'selfish': 15594,
#  'evil': 5954,
#  'humanity': 8037,
#  'passive': 12774,
#  'transport': 17841,
#  'cell': 2809,
#  'hair': 7427,
#  'bald': 1502,
#  'head': 7621,
#  'shave': 15788,
#  'grow': 7319,
#  'loose': 10185,
#  'ideal': 8194,
#  'retirement': 14815,
#  'stance': 16574,
#  'possession': 13466,
#  'weapon': 19040,
#  'mass': 10607,
#  'destruction': 4653,
#  'north': 11985,
#  'korea': 9603,
#  'escort': 5833,
#  'polo': 13374,
#  'diesel': 4777,
#  'grand': 7227,
#  'petrol': 13047,
#  'diet': 4778,
#  'black': 1960,
#  'hole': 7852,
#  'finite': 6402,
#  'morgan': 11314,
#  'freeman': 6676,
#  'correct': 3858,
#  'racism': 14138,
#  'quote': 14116,
#  'fab': 6125,
#  'currently': 4182,
#  'offer': 12237,
#  'stock': 16694,
#  'option': 12373,
#  'rsus': 15112,
#  'uber': 18078,
#  'distribute': 4986,
#  'identical': 8200,
#  'pencil': 12912,
#  'least': 9847,
#  'apple': 910,
#  'among': 669,
#  'jerry': 9153,
#  'seinfeld': 15579,
#  'hour': 7973,
#  'tape': 17236,
#  'presentation': 13633,
#  'late': 9773,
#  'rabies': 14129,
#  'vaccine': 18533,
#  'exposure': 6071,
#  'injection': 8628,
#  'dog': 5064,
#  'bite': 1948,
#  'britain': 2278,
#  'rule': 15142,
#  'standard': 16577,
#  'relocation': 14615,
#  'afraid': 345,
#  'everything': 5949,
#  'red': 14450,
#  'key': 9450,
#  'season': 15528,
#  'orange': 12380,
#  'virginity': 18783,
#  'wife': 19173,
#  'kill': 9496,
#  'emperor': 5611,
#  'palpatine': 12651,
#  'monetize': 11250,
#  'upload': 18429,
#  'copyright': 3832,
#  'chance': 2903,
#  'may': 10683,
#  'issue': 9009,
#  'switch': 17095,
#  'canon': 2572,
#  'tripod': 17914,
#  'member': 10819,
#  'moderation': 11194,
#  'moderator': 11195,
#  'nobody': 11937,
#  'funny': 6781,
#  'joke': 9221,
#  'london': 10162,
#  'pm': 13303,
#  'deduction': 4426,
#  'pls': 13285,
#  'advice': 297,
#  'monthly': 11292,
#  'expense': 6039,
#  'save': 15367,
#  'norway': 11993,
#  'mortgage': 11330,
#  'apartment': 875,
#  'stereotype': 16654,
#  'kingdom': 9517,
#  'twitter': 18049,
#  'business': 2428,
#  'source': 16342,
#  'transfer': 17812,
#  'skrill': 16073,
#  'paypal': 12846,
#  'send': 15618,
#  'withdraw': 19235,
#  'earphone': 5348,
#  'deep': 4430,
#  'bass': 1620,
#  'eligible': 5540,
#  'yojana': 19438,
#  'forward': 6616,
#  'engineer': 5683,
#  'suit': 16909,
#  'abuse': 78,
#  'abusive': 80,
#  'several': 15708,
#  'ex': 5962,
#  'past': 12780,
#  'abuser': 79,
#  'gross': 7311,
#  'ctc': 4130,
#  'weekly': 19073,
#  'paycheck': 12838,
#  'yearly': 19405,
#  'employer': 5622,
#  'agree': 391,
#  'upon': 18433,
#  'prosper': 13831,
#  'town': 17759,
#  'kerala': 9429,
#  'confidence': 3617,
#  'clarity': 3181,
#  'anyone': 860,
#  'relation': 14583,
#  'greek': 7276,
#  'god': 7120,
#  'hindu': 7791,
#  'parallelism': 12704,
#  'draw': 5186,
#  'mythology': 11537,
#  'egyptian': 5466,
#  'music': 11485,
#  'spotify': 16479,
#  'fix': 6436,
#  'fund': 6766,
#  'live': 10092,
#  'cologne': 3402,
#  'robert': 14988,
#  'de': 4345,
#  'niro': 11904,
#  'al': 469,
#  'pacino': 12595,
#  'regard': 14524,
#  'actor': 184,
#  'prefer': 13591,
#  'small': 16141,
#  'animal': 771,
#  'kiss': 9531,
#  'besides': 1785,
#  'delete': 4494,
#  'chat': 2944,
#  'dm': 5034,
#  'addict': 214,
#  'private': 13697,
#  'order': 12389,
#  'follow': 6545,
#  'able': 42,
#  'investigator': 8881,
#  'startup': 16605,
#  'accelerator': 92,
#  'check': 2957,
#  'wifi': 19174,
#  'history': 7813,
#  'router': 15092,
#  'mobile': 11178,
#  'network': 11774,
#  'significance': 15953,
#  'battle': 1635,
#  'somme': 16297,
#  'contrast': 3768,
#  'rostov': 15067,
#  'riyadh': 14960,
#  'creative': 4007,
#  'college': 3393,
#  'admission': 251,
#  'essay': 5847,
#  'public': 13928,
#  'applicant': 914,
#  'cover': 3940,
#  'patch': 12789,
#  'enter': 5718,
#  'pursue': 13998,
#  'refuse': 14520,
#  'ben': 1743,
#  'affleck': 339,
#  'shine': 15836,
#  'bale': 1504,
#  'batman': 1629,
#  'please': 13278,
#  'start': 16602,
#  'hyderabad': 8088,
#  'possessive': 13467,
#  'lord': 10190,
#  'krishna': 9623,
#  'father': 6224,
#  'combination': 3429,
#  'along': 578,
#  'enhance': 5688,
#  'must': 11496,
#  'screenshot': 15489,
#  'mac': 10293,
#  'macbook': 10301,
#  'pro': 13706,
#  'instruction': 8718,
#  'executive': 6002,
#  'recruiter': 14434,
#  'psychological': 13906,
#  'fulfill': 6750,
#  'collect': 3387,
#  'tv': 18034,
#  'show': 15890,
#  'die': 4774,
#  'fluent': 6510,
#  'demonitization': 4538,
#  'rupee': 15156,
#  'note': 12008,
#  'estate': 5855,
#  'sector': 15552,
#  'impact': 8342,
#  'scrap': 15479,
#  'will': 19188,
#  'lecture': 9854,
#  'conduct': 3604,
#  'workshop': 19288,
#  'almost': 573,
#  'week': 19070,
#  'prozac': 13871,
#  'antisocial': 846,
#  'event': 5934,
#  'behavior': 1714,
#  'mood': 11301,
#  'daily': 4250,
#  'robotics': 14996,
#  'development': 4696,
#  'hate': 7574,
#  'hillary': 7779,
#  'clinton': 3241,
#  'reason': 14365,
#  'dislike': 4927,
#  'period': 12969,
#  'ritual': 14955,
#  'hinduism': 7792,
#  'cook': 3805,
#  'especially': 5841,
#  'culture': 4156,
#  'activity': 182,
#  'responsibility': 14775,
#  'alone': 577,
#  'equally': 5779,
#  'atheism': 1194,
#  'lack': 9691,
#  'belief': 1729,
#  'term': 17387,
#  'claim': 3168,
#  'jack': 9052,
#  'dorsey': 5124,
#  'assassin': 1135,
#  'creed': 4018,
#  'series': 15672,
#  'robe': 14987,
#  'inkjet': 8635,
#  'printer': 13685,
#  'color': 3414,
#  'ink': 8634,
#  'document': 5055,
#  'create': 4002,
#  'complement': 3520,
#  'shop': 15866,
#  'creativity': 4009,
#  'continue': 3751,
#  'presidential': 13640,
#  'campaign': 2540,
#  'democratic': 4525,
#  'candidate': 2560,
#  'serve': 15682,
#  'nominee': 11953,
#  'successor': 16878,
#  'headphone': 7629,
#  'antenna': 820,
#  'channel': 2913,
#  'install': 8697,
#  'inbuilt': 8417,
#  'growth': 7321,
#  'automation': 1319,
#  'apart': 873,
#  'himalayan': 7784,
#  'duke': 5268,
#  'ktm': 9634,
#  'tour': 17745,
#  'disadvantage': 4866,
#  'list': 10068,
#  'nse': 12053,
#  'benefit': 1752,
#  'derivative': 4610,
#  'object': 12144,
#  'position': 13457,
#  'respect': 14764,
#  'continuous': 3753,
#  'fun': 6759,
#  'neutron': 11795,
#  'gpa': 7195,
#  'enough': 5703,
#  'top': 17703,
#  'harvard': 7559,
#  'sufficient': 16896,
#  'school': 15434,
#  ...}

# %% [markdown]
# ##### Word2Vec

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')
vectors_w2v = df['cleans']

# %% [markdown]
# ### Train/Test Selection

# %%
dy = df['is_duplicate']
dx = vectors_idf

# %% [markdown]
# Setting aside about 30% of the training set for validation later.

# %%
xtrain, xtest, ytrain, ytest = train_test_split(dx, dy, test_size=0.50, stratify=dy)

# %%
xtrain.shape
# Out:
# (202143, 19549)

# %% [markdown]
# ### Modeling
#
# Different modeling techniques can be used:
#
# - logistic regression
# - XGBoost
# - LSTMs
# - etc

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(xtrain, ytrain)

ypred_lr = lr.predict(xtest)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from xgboost import XGBClassifier

xg = XGBClassifier()
xg.fit(xtrain, ytrain)

ypred_xg = xg.predict(xtest)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:45:54] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1645117899018/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
from sklearn.naive_bayes import BernoulliNB

nb = BernoulliNB()
nb.fit(xtrain, ytrain)

ypred_nb = nb.predict(xtest)

# %%
from tensorflow.keras import Sequential, losses, metrics
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras import Input

# %%
model = Sequential()
model.add(LSTM(1024, activation='relu', recurrent_activation='sigmoid'))
model.add(Dense(len(tfidf.vocabulary_)))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc', 'mse'])

# %%
history = model.fit(xtrain.toarray(), ytrain,
                    epochs=50,
                    batch_size=32,
                    validation_split=0.2,
                    validation_data=(xtest, ytest),)
# Out:
# Epoch 1/50
# 2022-06-03 18:46:13.622514: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/lsantos/Documents/lighthouse-data-notes/week_9/day_3/mini_project_V_v1.1.ipynb Cell 63' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/lsantos/Documents/lighthouse-data-notes/week_9/day_3/mini_project_V_v1.1.ipynb#ch0000062?line=0'>1</a> history = model.fit(xtrain.toarray(), ytrain,
#       <a href='vscode-notebook-cell:/Users/lsantos/Documents/lighthouse-data-notes/week_9/day_3/mini_project_V_v1.1.ipynb#ch0000062?line=1'>2</a>                     epochs=50,
#       <a href='vscode-notebook-cell:/Users/lsantos/Documents/lighthouse-data-notes/week_9/day_3/mini_project_V_v1.1.ipynb#ch0000062?line=2'>3</a>                     batch_size=32,
#       <a href='vscode-notebook-cell:/Users/lsantos/Documents/lighthouse-data-notes/week_9/day_3/mini_project_V_v1.1.ipynb#ch0000062?line=3'>4</a>                     validation_split=0.2,
#       <a href='vscode-notebook-cell:/Users/lsantos/Documents/lighthouse-data-notes/week_9/day_3/mini_project_V_v1.1.ipynb#ch0000062?line=4'>5</a>                     validation_data=(xtest, ytest),)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py:1129, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1126'>1127</a> except Exception as e:  # pylint:disable=broad-except
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1127'>1128</a>   if hasattr(e, "ag_error_metadata"):
# -> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1128'>1129</a>     raise e.ag_error_metadata.to_exception(e)
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1129'>1130</a>   else:
#    <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py?line=1130'>1131</a>     raise
#
# ValueError: in user code:
#
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/engine/training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/engine/training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/engine/training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/engine/training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/opt/homebrew/Caskroom/miniforge/base/envs/lighthouse/lib/python3.8/site-packages/keras/engine/input_spec.py", line 213, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#
#     ValueError: Exception encountered when calling layer "sequential_1" (type Sequential).
#
#     Input 0 of layer "lstm_1" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 19549)
#
#     Call arguments received:
#       • inputs=tf.Tensor(shape=(None, 19549), dtype=float32)
#       • training=True
#       • mask=None

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print(classification_report(ytest, ypred_lr))
print(classification_report(ytest, ypred_xg))
print(classification_report(ytest, ypred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81    127512
#            1       0.70      0.52      0.60     74632
#
#     accuracy                           0.74    202144
#    macro avg       0.73      0.69      0.70    202144
# weighted avg       0.74      0.74      0.73    202144
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.93      0.82    127512
#            1       0.77      0.40      0.52     74632
#
#     accuracy                           0.73    202144
#    macro avg       0.75      0.66      0.67    202144
# weighted avg       0.74      0.73      0.71    202144
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77    127512
#            1       0.61      0.69      0.65     74632
#
#     accuracy                           0.72    202144
#    macro avg       0.71      0.72      0.71    202144
# weighted avg       0.73      0.72      0.73    202144

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig,((ax0, ax1), (ax2, ax3)) = plt.subplots(2, 2, figsize=(12, 10), sharex='all', sharey='all')

sns.heatmap(confusion_matrix(ytest,ypred_lr), annot=True, fmt='.2f', ax=ax0)
sns.heatmap(confusion_matrix(ytest,ypred_xg), annot=True, fmt='.2f', ax=ax1)
sns.heatmap(confusion_matrix(ytest,ypred_nb), annot=True, fmt='.2f', ax=ax2)
sns.heatmap(confusion_matrix(ytest,ypred_xg), annot=True, fmt='.2f', ax=ax3)

ax0.set(title="Evaluating Question Similarity (LogReg)",
      # xlabel="Predicted",
      ylabel="Actual",
      )

ax1.set(title="Evaluating Question Similarity (XGBoost)",
      # xlabel="Predicted",
      # ylabel="Actual",
      )

ax2.set(title="Evaluating Question Similarity (NBayes)",
      xlabel="Predicted",
      ylabel="Actual",
      )

ax3.set(title="Evaluating Question Similarity (LSTM)",
      xlabel="Predicted",
      # ylabel="Actual",
      )
 
plt.tight_layout()
plt.show()
