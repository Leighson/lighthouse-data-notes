# %% [markdown]
# # Matplotlib Tutorial

# %% [markdown]
# ### Imports

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib
import numpy as np
import pandas as pd

# %% [markdown]
# ### Getting Started

# %%
x = np.linspace(0, 10, 20) # generate 20 datapoints between 0 and 10
y = x**2

# %%
plt.plot(x,y)
plt.title('Our First Plot')
plt.xlabel('X Label')
plt.ylabel('Y Label')
# Out:
# Text(0, 0.5, 'Y Label')

# %%
# plt.subplot(nrow, ncols, plot_number)
plt.subplot(1, 2, 1)
plt.plot(x, y, 'red')

plt.subplot(1, 2, 2)
plt.plot(x, y, 'green')

plt.show()

# %%
# object-oriented interface
fig = plt.figure()

ax = fig.add_axes([1, 1, .8, 1.5]) # left, bottom, width, and height positions where axes are placed
ax.plot(x, y, 'purple')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_title('Our 1st Plot Using an Object-Oriented Approach')
# Out:
# Text(0.5, 1.0, 'Our 1st Plot Using an Object-Oriented Approach')

# %%
fig2 = plt.figure()

axes1 = fig2.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig2.add_axes([0.2, 0.5, 0.4, 0.3])

# %%
axes1.plot(x, y)
axes2.plot(y, x)

# %%
fig, ax = plt.subplots(nrows=3, ncols=3)

ax[0,1].plot(x,y)
ax[1,2].plot(y,x)

ax[0,1].set_title('hello world')
ax[0,1].set_ylabel('hello')
ax[0,1].set_xlabel('world')

ax[1,2].set_title('hello world')
ax[1,2].set_ylabel('hello')
ax[1,2].set_xlabel('world')

plt.tight_layout()

# %%
fig = plt.figure(figsize=(14,2), dpi=540/8)

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,4), dpi=100)

ax[0].plot(x,y)
ax[1].plot(y,x)

fig.savefig('my_figure.png')

plt.tight_layout()

# %%
plt.imshow(mpimg.imread('my_figure.png'))

# %%
fig = plt.figure(figsize=(8,6), dpi=60)
ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, label='X^2')
ax.plot(x,x**3, 'red', label='X^3')

ax.legend()

# %%
fig = plt.figure(figsize=(8,6), dpi=60)
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', linewidth=3, linestyle='--', marker='o', markersize=8, label='format')

ax.legend()

# %%
fig = plt.figure(figsize=(8,6), dpi=60)
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, ls='--')

ax.set_xlim([0,1])
ax.set_ylim([0,5])

ax.axis('tight')
# Out:
# (-0.5, 10.5, -5.0, 105.0)

# %% [markdown]
# # Walkthrough

# %%
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## Line Plot

# %% [markdown]
# In this example, we will create a sine wave with x-range from 0 to 100. We will generate data using `Numpy`.

# %%
# 200 values from the interval <0, 100>, equidistantly divided
x = np.linspace(0, 100, 200)
y = np.sin(x)

# a line plot
plt.plot(x,y,'red')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# 200 random values from the interval <0,10>
x = 10*np.random.rand(200,1)

# 200 random values from the interval <0,15>
y = 15*np.random.rand(200,1)

# a scatter plot
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Histogram

# %%
# 200 random values from the interval <0,15>
y = 15*np.random.rand(200,1)

# a histogram with 20 bins
plt.hist(y, bins=20)
plt.show()

# %% [markdown]
# # Graphs on Common Axes

# %% [markdown]
# in this example, we will plot 2 mathematical functions (sin(x), sin(x)*cos(x)) on one figure with shared axis.

# %%
#200 values from the interval <0,100>, equidistantly divided
x = np.linspace(0,100,200)

# sin(x) values
y1 = np.sin(x)

# sin(x)*cos(x) values
y2 = (np.sin(x))*(np.cos(x))

# a line plot of sin(x), red line
plt.plot(x,y1,'red')

# a line plot of sin(x)*cos(x), blue line
plt.plot(x,y2,'blue')
plt.show()

# %% [markdown]
# # Subplots

# %% [markdown]
# Let's continue with the example above but with one small change. Now we want to have a separate figure with its own axis for each function.

# %%
# the first figure
plt.subplot(2,1,1)
plt.plot(x,y1,'red')
plt.title('sin(x)')

# the second figure
plt.subplot(2,1,2)
plt.plot(x,y2,'blue')
plt.title('sin(x)*(cos(x))')

# automatically adjust the subplot parameterrs to give a specified padding
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Load Iris data to a data-frame

# %%
# load iris dataset
iris = datasets.load_iris()

# create dataframe
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# create target
iris_df['target'] = iris.target

# map the target values to the target names
iris_df['target_name'] = iris_df.target.map(
    {0: 'setosa',
     1: 'versicolor',
     2: 'virginica'}
)

# %% [markdown]
# ### Print the top 5 rows of the created data frame

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target target_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %% [markdown]
# ### Now, let's plot a scatter plot of sepal length and sepal width for each type of the Iris flower

# %%
# Iris setosa
setosa = iris_df[iris_df.target_name == 'setosa']

# Iris versicolor
versicolor = iris_df[iris_df.target_name == 'versicolor']

# Iris virginica
virginica = iris_df[iris_df.target_name == 'virginica']

# plot setosa
plt.scatter(setosa['sepal length (cm)'], setosa['sepal width (cm)'], marker = 'o', color = 'red', label = 'versicolor')

# plot versicolor
plt.scatter(versicolor['sepal length (cm)'], versicolor['sepal width (cm)'], marker ='o', color = 'green', label = 'versicolor')

# plot virginica
plt.scatter(virginica['sepal length (cm)'], virginica['sepal width (cm)'], marker ='o', color = 'blue', label = 'virginica')

# legend location
plt.legend(loc='upper right')

# plot title
plt.title('Iris flower')

# x-axis titled
plt.xlabel('sepal length (cm)')

# y-axis title
plt.ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# ## Annotations

# %% [markdown]
# If we want to add annotations to the figure we crated in the example above, we can do that by making the following changes in the code.

# %%
# plot setosa
plt.scatter(setosa['sepal length (cm)'], setosa['sepal width (cm)'], marker = 'o', color = 'red', label = 'versicolor')

# plot versicolor
plt.scatter(versicolor['sepal length (cm)'], versicolor['sepal width (cm)'], marker ='o', color = 'green', label = 'versicolor')

# plot virginica
plt.scatter(virginica['sepal length (cm)'], virginica['sepal width (cm)'], marker ='o', color = 'blue', label = 'virginica')

# new lines of code
# it can be tricky to find the right coordinates for the first time
###################

plt.annotate('Setosa', xy = (5.0, 3.5),
             xytext = (4.25, 4.0), arrowprops = {'color':'red'})
plt.annotate('versicolor', xy =(7.2,3.6),
             xytext = (6.5,4.0), arrowprops={'color':'red'})
plt.annotate('virginica', xy =(5.05,1.95),
             xytext = (5.5,1.75), arrowprops={'color':'red'})
###################

# legend location
plt.legend(loc='upper right')

# plot title
plt.title('Iris flower')

# x-axis titled
plt.xlabel('sepal length (cm)')

# y-axis title
plt.ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %%
matplotlib.rcParams['axes.labelcolor'] = 'white'

# %%
my_pie = np.array([45, 25, 10, 5, 15])
beverage = ['Water', 'Juice', 'Beer', 'Wine', 'Pop']

plt.title('Sales of Beverages at Some Restaurant', color='white')
plt.pie(my_pie, textprops={'color' : 'white'}, labels=beverage, autopct='%1.f%%', shadow=True, explode = [0, 0, .2, 0, 0])
plt.show()
