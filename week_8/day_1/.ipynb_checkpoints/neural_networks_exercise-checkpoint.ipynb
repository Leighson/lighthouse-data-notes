# %% [markdown]
# ## Practicing Neural Networks with the fashion MNIST dataset
# ---------------------------------

# %% [markdown]
# ### Loading the fashion MNIST data
# The data can be loaded directly from keras (`keras.datasets.fashion_mnist`).

# %%
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler

# %%
fashion_mnist = keras.datasets.fashion_mnist
(xtrain, ytrain), (xtest, ytest) = fashion_mnist.load_data()

# %%
# class names are not included, need to create them to plot the images  
classes = ['top', 'trouser', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'boot']

# %% [markdown]
# ##### returns 4 numpy arrays

# %% [markdown]
# - 2 training sets
# - 2 test sets

# %% [markdown]
# ##### images

# %% [markdown]
# - 28x28 arrays
# - 0 to 255 pixel values

# %% [markdown]
# ##### labels

# %% [markdown]
# - 0 to 9 array of integers, class of clothings

# %% [markdown]
# ##### training set

# %% [markdown]
# - 60,000 images
# - 10,000 images testing set

# %% [markdown]
# -------------------
# ### Data Exploration
#
# - **Task 1:** Explore the pictures and labels.
#     - Try displaying a picture of each class in jupyter.
#
#
# - **Task 2:** Normalize the data to be between 0 and 1.
#     - Write down in a new markdown cell, **why** should we do this?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ytrain.shape
# Out:
# (60000,)

# %%
xtrain.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# ## Task 1: Visualize Sample Images

# %%
rows = 3
cols = 8
fig,ax = plt.subplots(figsize=(16,6), nrows=rows, ncols=cols)

count = 0
for i in range(rows):
    for j in range(cols):
        ax[i,j].imshow(xtrain[count])
        count += 1

plt.tight_layout()
plt.show()

# %%
class_list = []
for label in ytrain[:rows*cols]:
    class_list.append(classes[label])
np.array(class_list)
# Out:
# array(['boot', 'top', 'top', 'dress', 'top', 'pullover', 'sneaker',
#        'pullover', 'sandal', 'sandal', 'top', 'boot', 'sandal', 'sandal',
#        'sneaker', 'boot', 'trouser', 'top', 'shirt', 'coat', 'dress',
#        'trouser', 'coat', 'bag'], dtype='<U8')

# %% [markdown]
# ## Task 2: Normalize Data

# %% [markdown]
# FIrst, convert the images to a 1D vector and fit/transform using a standard scaler.

# %%
train_images[0].shape
# Out:
# (28, 28)

# %%
n, h, w = xtrain.shape
x = train_images.reshape((n, h*w)).astype('float') / 255
y = to_categorical(ytrain, num_classes=10)

# %%
x.shape
# Out:
# (60000, 784)

# %% [markdown]
# ----------------------
# ### Training NN model
#
# Step 1  -  Build the architecture
#
# Step 2  -  Compile the model
#
# Step 3  -  Train the model
#
# Step 4  -  Evaluate the model

# %%
network = models.Sequential()
# Out:
# 2022-05-26 05:36:16.138613: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-26 05:36:16.140038: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-26 05:36:16.140289: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (bf26cc2cc811): /proc/driver/nvidia/version does not exist
# 2022-05-26 05:36:16.155828: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
network.add(layers.Dense(784, activation='relu', input_shape=28*28)
