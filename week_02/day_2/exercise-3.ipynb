# %%
import pandas as pd

# %% [markdown]
# ### Download the data and load it to Pandas.
#
# You can find them [here](https://drive.google.com/file/d/1NY6cmF9Shjw-dD7BD6bNmfcIVz-kQcFR/view?usp=sharing).

# %%
titles = pd.read_csv('data/titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### Using `groupby()`, count the number of films that have been released in each decade in the history of cinema.

# %%
# create bins to define the decades
bins = [x*10 for x in range(189, 204)]
# use groupby on the categorical series to count number of titles for each bin
titles.groupby(pd.cut(titles['year'], bins)).title.count()
# Out:
# year
# (1890, 1900]        7
# (1900, 1910]       55
# (1910, 1920]     7617
# (1920, 1930]     8490
# (1930, 1940]    10277
# (1940, 1950]     8675
# (1950, 1960]    13113
# (1960, 1970]    18166
# (1970, 1980]    18351
# (1980, 1990]    20746
# (1990, 2000]    22672
# (2000, 2010]    42247
# (2010, 2020]    61847
# (2020, 2030]       67
# Name: title, dtype: int64

# %% [markdown]
# ### Use `groupby()` count the number of "Hamlet" films made in each decade.

# %%
# use previous bins decades and filter by title 'Hamlet'
titles[titles['title'] == 'Hamlet'].groupby(pd.cut(titles['year'], bins)).title.count()
# Out:
# year
# (1890, 1900]    0
# (1900, 1910]    1
# (1910, 1920]    2
# (1920, 1930]    1
# (1930, 1940]    0
# (1940, 1950]    1
# (1950, 1960]    1
# (1960, 1970]    2
# (1970, 1980]    2
# (1980, 1990]    2
# (1990, 2000]    2
# (2000, 2010]    1
# (2010, 2020]    3
# (2020, 2030]    0
# Name: title, dtype: int64

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

# %%
def df_filter(table, field, value):
    return table[table[field] == value]

cast.pipe(df_filter, 'n', 1).pipe(df_filter, 'type', 'actress'
                                  ).groupby(pd.cut(cast['year'], bins)).count()
# Out:
#                            title  year              name     type  \
# 2455420      Queen of the Damned  2002           Aaliyah  actress
# 2455503            Til en ukjent  1990       Hilde Aaroe  actress
# 2455508  A Day Without a Mexican  2004    Caroline Aaron  actress
# 2455520             Call Waiting  2004    Caroline Aaron  actress
# 2455521             Call Waiting  2004    Caroline Aaron  actress
# ...                          ...   ...               ...      ...
# 3634253                 Doyumsuz  1990       Bahar ?ztan  actress
# 3634265                   Kadife  2012      Ayta? ?ztuna  actress
# 3634308               Dig og mig  2008  Julie R. ?lgaard  actress
# 3634328       Mimi og madammerne  1998         Tammi ?st  actress
# 3634335                Ved vejen  1988         Tammi ?st  actress
#
#             character    n
# 2455420  Queen Akasha  1.0
# 2455503           Ane  1.0
# 2455508     Aunt Gigi  1.0
# 2455520   Judy Baxter  1.0
# 2455521    Carol Lane  1.0
# ...               ...  ...
# 3634253         Bahar  1.0
# 3634265    Kadife Ana  1.0
# 3634308     Stephanie  1.0
# 3634328          Mimi  1.0
# 3634335       Katinka  1.0
#
# [45614 rows x 6 columns]

# %% [markdown]
# ### In the 1950s taken as a whole, how many total roles were available to actors, and how many to actresses, for each "n" number 1 through 5?

# %%
for n in range(1, 6):
    print(cast.pipe(df_filter, 'n', n).pipe(df_filter, 'type', 'actress').groupby(pd.cut(cast['year'], bins)).count()['title'].iloc[6])
# Out:
# 2975
# 4614
# 3181
# 2882
# 2606

# %%
for n in range(1, 6):
    print(cast.pipe(df_filter, 'n', n).pipe(df_filter, 'type', 'actor').groupby(pd.cut(cast['year'], bins)).count()['title'].iloc[6])
# Out:
# 6709
# 4610
# 5638
# 5622
# 5608

# %% [markdown]
# ### Use `groupby()` to determine how many roles are listed for each of the Pink Panther movies.

# %%
cast.pipe(df_filter, 'title', 'Pink Panther')
# Out:
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []

# %% [markdown]
# ### List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %%
cast.pipe(df_filter, 'name', 'Frank Oz').groupby('title').filter(lambda x: len(x) > 1).sort_values(by=['year', 'title'])
# Out:
#                                         title  year      name   type  \
# 1672035                      The Muppet Movie  1979  Frank Oz  actor
# 1672036                      The Muppet Movie  1979  Frank Oz  actor
# 1672037                      The Muppet Movie  1979  Frank Oz  actor
# 1672038                      The Muppet Movie  1979  Frank Oz  actor
# 1672039                      The Muppet Movie  1979  Frank Oz  actor
# 1672040                      The Muppet Movie  1979  Frank Oz  actor
# 1672041                      The Muppet Movie  1979  Frank Oz  actor
# 1672042                      The Muppet Movie  1979  Frank Oz  actor
# 1671990        An American Werewolf in London  1981  Frank Oz  actor
# 1671991        An American Werewolf in London  1981  Frank Oz  actor
# 1672022                The Great Muppet Caper  1981  Frank Oz  actor
# 1672023                The Great Muppet Caper  1981  Frank Oz  actor
# 1672024                The Great Muppet Caper  1981  Frank Oz  actor
# 1672025                The Great Muppet Caper  1981  Frank Oz  actor
# 1672026                The Great Muppet Caper  1981  Frank Oz  actor
# 1672027                The Great Muppet Caper  1981  Frank Oz  actor
# 1672020                      The Dark Crystal  1982  Frank Oz  actor
# 1672021                      The Dark Crystal  1982  Frank Oz  actor
# 1672043            The Muppets Take Manhattan  1984  Frank Oz  actor
# 1672044            The Muppets Take Manhattan  1984  Frank Oz  actor
# 1672045            The Muppets Take Manhattan  1984  Frank Oz  actor
# 1672046            The Muppets Take Manhattan  1984  Frank Oz  actor
# 1672047            The Muppets Take Manhattan  1984  Frank Oz  actor
# 1672048            The Muppets Take Manhattan  1984  Frank Oz  actor
# 1672049            The Muppets Take Manhattan  1984  Frank Oz  actor
# 1671993                      Follow That Bird  1985  Frank Oz  actor
# 1671994                      Follow That Bird  1985  Frank Oz  actor
# 1671995                      Follow That Bird  1985  Frank Oz  actor
# 1672028            The Muppet Christmas Carol  1992  Frank Oz  actor
# 1672029            The Muppet Christmas Carol  1992  Frank Oz  actor
# 1672030            The Muppet Christmas Carol  1992  Frank Oz  actor
# 1672031            The Muppet Christmas Carol  1992  Frank Oz  actor
# 1672032            The Muppet Christmas Carol  1992  Frank Oz  actor
# 1672033            The Muppet Christmas Carol  1992  Frank Oz  actor
# 1672034            The Muppet Christmas Carol  1992  Frank Oz  actor
# 1672000                Muppet Treasure Island  1996  Frank Oz  actor
# 1672001                Muppet Treasure Island  1996  Frank Oz  actor
# 1672002                Muppet Treasure Island  1996  Frank Oz  actor
# 1672003                Muppet Treasure Island  1996  Frank Oz  actor
# 1672004                    Muppets from Space  1999  Frank Oz  actor
# 1672005                    Muppets from Space  1999  Frank Oz  actor
# 1672006                    Muppets from Space  1999  Frank Oz  actor
# 1672007                    Muppets from Space  1999  Frank Oz  actor
# 1672016  The Adventures of Elmo in Grouchland  1999  Frank Oz  actor
# 1672017  The Adventures of Elmo in Grouchland  1999  Frank Oz  actor
# 1672018  The Adventures of Elmo in Grouchland  1999  Frank Oz  actor
#
#                                                  character     n
# 1672035                                         Miss Piggy   2.0
# 1672036                                        Fozzie Bear   2.0
# 1672037                                             Animal   2.0
# 1672038                                      Sam the Eagle   2.0
# 1672039                                   Doc Hopper's Men   2.0
# 1672040                                       Marvin Suggs   2.0
# 1672041                           Swedish Chef (assistant)   2.0
# 1672042                                     Motorcycle Guy   2.0
# 1671990                                        Mr. Collins  13.0
# 1671991                                         Miss Piggy  13.0
# 1672022                                         Miss Piggy   2.0
# 1672023                                        Fozzie Bear   2.0
# 1672024                                             Animal   2.0
# 1672025                                      Sam the Eagle   2.0
# 1672026                                             Gramps   2.0
# 1672027                                       Swedish Chef   2.0
# 1672020            Aughra, a Keeper Of Secrets (performer)   3.0
# 1672021                            Chamberlain (performer)   3.0
# 1672043                                         Miss Piggy   2.0
# 1672044                                             Fozzie   2.0
# 1672045                                             Animal   2.0
# 1672046                                               Bert   2.0
# 1672047                                     Cookie Monster   2.0
# 1672048                     Ocean Breeze Soap Board Member   2.0
# 1672049                                      Sam the Eagle   2.0
# 1671993                                     Cookie Monster   3.0
# 1671994                                               Bert   3.0
# 1671995                                             Grover   3.0
# 1672028                       Miss Piggy as Emily Cratchit   5.0
# 1672029                           Fozzie Bear as Fozziewig   5.0
# 1672030  Sam the Eagle as Headmaster of Junior High Gra...   5.0
# 1672031                                             Animal   5.0
# 1672032                                 George the Janitor   5.0
# 1672033                          Horse and Carriage Driver   5.0
# 1672034                                 Vegetable Salesman   5.0
# 1672000                                         Miss Piggy  14.0
# 1672001                                        Fozzie Bear  14.0
# 1672002                                      Sam the Eagle  14.0
# 1672003                                             Animal  14.0
# 1672004                                         Miss Piggy   7.0
# 1672005                                        Fozzie Bear   7.0
# 1672006                                             Animal   7.0
# 1672007                                      Sam the Eagle   7.0
# 1672016                                               Bert  16.0
# 1672017                                             Grover  16.0
# 1672018                                     Cookie Monster  16.0

# %% [markdown]
# ### List each of the characters that Frank Oz has portrayed at least twice.

# %%
cast.pipe(df_filter, 'name', 'Frank Oz').groupby('character').filter(lambda x: len(x) > 1).sort_values('character')
# Out:
#                                                   title  year      name  \
# 1672031                      The Muppet Christmas Carol  1992  Frank Oz
# 1672037                                The Muppet Movie  1979  Frank Oz
# 1672024                          The Great Muppet Caper  1981  Frank Oz
# 1672045                      The Muppets Take Manhattan  1984  Frank Oz
# 1672006                              Muppets from Space  1999  Frank Oz
# 1672003                          Muppet Treasure Island  1996  Frank Oz
# 1672016            The Adventures of Elmo in Grouchland  1999  Frank Oz
# 1671994                                Follow That Bird  1985  Frank Oz
# 1672046                      The Muppets Take Manhattan  1984  Frank Oz
